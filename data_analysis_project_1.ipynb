# %% [markdown]
# <a href="https://colab.research.google.com/github/DaliniPillai/data_analysis_project_one/blob/main/data_analysis_project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Analysis Project 1

# %% [markdown]
# I started off my cleaning the Data as much as I could by searching for null values. I saw there were two columns with only na and decided to drop them. I tried to make a new data frame and use that to make my visualizations but came into some errors so I decided to locate Hillcrest High school and Forest Hill High School with loc and saving them each in a variable. Then I decided to use those variable in my visualizations. I came across a lot of errors and was stuck for an hour or so, especially with type errors because most of the columns were objects and for the graph it kept saying there weren't any numbers to make one. When I tried to change the type, I came across another error that I couldn't convert the string "s" and got rid of it by using df.drop.

# %%
#import packages 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
from numpy.random import randn
np.random.seed(123)




df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

#Using .head() to look at the Data 
df.head(20)
df.shape


#check for missing values, dropping columns with only na 
df.isnull().sum()

drop_cols = ['Number Scoring CR','Percent Scoring CR']
df.drop(drop_cols, axis= 1, inplace=True)


#Creating a new DataFrame 
df2 = df[['School Name','Regents Exam','Percent Scoring 65 or Above', 'Mean Score']]

#renaming column 
df2 = df2.rename(columns={'Mean Score':'Mean test Scores'})

#Filtering columns to get more info on the High school I went to vs a High school in the same area
#I was able to locate the schools but could not figure out how to use the two schools to make a plot

result1 = df.loc[df['School Name'] == 'Hillcrest High School']
result2 = df.loc[df['School Name'] == 'Forest Hills High School']
df.loc

print("result 1:", result1)
print("result 2:", result2)


df.head(100)

#I was having a type error, could not make a plot with my new data frame but even when I tried to change an object to a float it didnt work
#I tired to get rid of the "s" value because of the type error I was having
df = df.set_index("Mean Score")
df = df.drop("s", axis= 0)


result1.plot.scatter(x='Mean Score', y='Percent Scoring 65 or Above')
result2.plot.scatter(x='Mean Score', y='Percent Scoring 65 or Above')

result1.hist()

result2.hist()
# Out:
# result 1:        School DBN  ... Percent Scoring 80 or Above
# 15616      28Q505  ...                        12.9
# 15617      28Q505  ...                        13.2
# 15618      28Q505  ...                         8.8
# 15619      28Q505  ...                         0.8
# 15620      28Q505  ...                         6.7
# ...           ...  ...                         ...
# 198880     28Q505  ...                        52.5
# 198881     28Q505  ...                        43.4
# 198882     28Q505  ...                          43
# 198883     28Q505  ...                        42.1
# 198884     28Q505  ...                        41.9
#
# [473 rows x 13 columns]
# result 2:        School DBN  ... Percent Scoring 80 or Above
# 15578      28Q440  ...                        41.1
# 15579      28Q440  ...                        44.6
# 15580      28Q440  ...                           0
# 15581      28Q440  ...                        13.3
# ...
